# %% [markdown]
# 数组是非常基础的数据结构，在面试中，考察数组的题目一般在思维上都不难，主要是考察对代码的掌控能力
#
# 也就是说，想法很简单，但实现起来 可能就不是那么回事了。
#
# 首先要知道数组在内存中的存储方式，这样才能真正理解数组相关的面试题
#
# **数组是存放在连续内存空间上的相同类型数据的集合。**
#
# 数组可以方便的通过下标索引的方式获取到下标下对应的数据。
#
# 举一个字符数组的例子，如图所示：

# %% [markdown]
# ![jupyter](./image/算法通关数组.png)

# %%
from IPython.display import Image
Image("./image/算法通关数组.png",width=700,height=800)

# %% [markdown]
# 需要两点注意的是
#
# - 数组下标都是从0开始的。
# - 数组内存空间的地址是连续的
#
# 正是因为数组的在内存空间的地址是连续的，所以我们在删除或者增添元素的时候，就难免要移动其他元素的地址。

# %% [markdown]
# ![jupyter](./image/算法通关数组.png)

# %%
array_list = [3,4,2]
for i in range(len(array_list)):
    print(array_list[i],"id:",id(array_list[i]))
# Out:
# 3 id: 4368063216
# 4 id: 4368063248
# 2 id: 4368063184

# %%
array_list = [[],[],[]]
for i in range(len(array_list)):
    print(array_list[i],"id:",id(array_list[i]))
# Out:
# [] id: 4401319176
# [] id: 4401139976
# [] id: 4401141960
